# %%
import numpy as np
import cPickle as pickle
import matplotlib.pyplot as plt

# %%
means = pickle.load(open('means.p','r'))
print means[1:]
# Out:
# [[  9.11330570e+06   9.25863520e+05   2.06284000e+03   2.09662000e+03]
#  [  1.46277600e+08   3.26108691e+07   3.79886772e+06   3.39130000e+03]]

# %%
stds = pickle.load(open('stds.p','r'))
print stds[1:]
# Out:
# [[  3.40349783e+05   3.60268320e+04   2.37169506e+02   2.16079235e+02]
#  [  1.53599284e+07   4.60565900e+06   3.30818439e+05   2.35382179e+02]]

# %%
plt.plot(means[1:].T)
plt.show()
