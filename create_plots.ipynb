# %%
import numpy as np
import cPickle as pickle
import matplotlib.pyplot as plt

DATA_PATH = 'data/processed/'

# %% [markdown]
# Unsorted PUT

# %%
umeans = pickle.load(open(DATA_PATH+'put_unsorted_means.p','r'))
ustds = pickle.load(open(DATA_PATH+'put_unsorted_stds.p','r'))
x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,umeans[0,:], yerr=ustds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,umeans[1,:], yerr=ustds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,umeans[2,:], yerr=ustds[2,:], fmt='r--', label='1e5')
plt.title('Unsorted PUT Latency', fontsize=20)
plt.xscale('log')
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# Sorted PUT

# %%
means = pickle.load(open(DATA_PATH+'put_sorted_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'put_sorted_stds.p','r'))
x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Sorted PUT Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# GET sorted

# %%
means = pickle.load(open(DATA_PATH+'get_sorted_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'get_sorted_stds.p','r'))
x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Sorted GET Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# GET unsorted

# %%
means = pickle.load(open(DATA_PATH+'get_unsorted_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'get_unsorted_stds.p','r'))

x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Unsorted GET Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# UPDATE sorted

# %%
means = pickle.load(open(DATA_PATH+'update_sorted_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'update_sorted_stds.p','r'))

x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Sorted UPDATE Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# UPDATE unsorted

# %%
means = pickle.load(open(DATA_PATH+'update_unsorted_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'update_unsorted_stds.p','r'))

x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Unsorted UPDATE Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %% [markdown]
# Throughput 30% of each operation - gets, puts, and updates - out of 100 total operations

# %%
means = pickle.load(open(DATA_PATH+'throughput_unsorted_303030_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'throughput_unsorted_303030_stds.p','r'))

x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Unsorted Throughput Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()

# %%
means = pickle.load(open(DATA_PATH+'throughput_sorted_303030_means.p','r')) 
stds = pickle.load(open(DATA_PATH+'throughput_sorted_303030_stds.p','r'))

x = [1e2, 1e3, 1e4, 1e5]
plt.errorbar(x,means[0,:], yerr=stds[0,:], fmt='b^--', label='1e3')
plt.errorbar(x,means[1,:], yerr=stds[1,:], fmt='gs--', label='1e4')
plt.errorbar(x,means[2,:], yerr=stds[2,:], fmt='r--', label='1e5')
plt.xscale('log')
plt.title('Sorted Throughput Latency', fontsize=20)
plt.xlabel('Buffer size', fontsize=16) 
plt.ylabel('Time (s)', fontsize=16)
plt.legend(title='data size')
plt.show()
